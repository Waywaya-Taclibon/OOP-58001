# %% [markdown]
# <a href="https://colab.research.google.com/github/Whywhyaaaa/OOP-58001/blob/main/OOP_CONCEPTS_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Birds:
  def __init__(self,bird_name):
   self.bird_name = bird_name
  def flying_birds(self):
    print(f"{self.bird_name} flies above the clouds")
  def non_flying_birds(self):
    print(f"{self.bird_name} is the national bird of the Philippines")

vulture = Birds("Griffin Vulture")
crane = Birds("Common Crane")
emu = Birds("Emu")

vulture.flying_birds()
crane.flying_birds()
emu.non_flying_birds()
# Out:
# Griffin Vulture flies above the clouds
# Common Crane flies above the clouds
# Emu is the national bird of the Philippines

# %%
class foo:
  def __init__(self,a,b):
    self._a = a 
    self._b = b
  def add(self):
    return self.a + self._b
foo_object = foo(10,20)

  #foo_object.add()

foo_object.a = 6
foo_object.add()
# Out:
# 26

# %%
class Counter:
    def __init__(self):
        self.__current = 0

    def increment(self):
        self.__current += 1 #current = current +1

    def value(self):
        return self.__current

    def reset(self):
        self.__current = 0

counter = Counter()
counter.increment()

#counter.increment()
#counter.increment()

print(counter.__value)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-737f9014c54e> in <module>()
#      18 #counter.increment()
#      19
# ---> 20 print(counter.__value)
#
# AttributeError: 'Counter' object has no attribute '__value'

# %%
class Person:
  def __init__(self,fname,sname):
    self.fname = fname
    self.sname = sname
  def printname(self):
    print(self.fname,self.sname)

x = Person("Way","waya")
x.printname()

class Teacher(Person):
  pass

x = Teacher("yet","ma")
x.printname()
# Out:
# Way waya
# yet ma

# %%
class RegularPolygon:
    def __init__(self, side):
        self._side = side
class Square(RegularPolygon):
    def area(self):
        return self._side * self._side
class EquilateralTriangle(RegularPolygon):
    def area(self):
        return self._side * self._side * 0.433

obj1 = Square(4)
obj2 = EquilateralTriangle(3)

print(obj1.area())
print(obj2.area())
# Out:
# 16
# 3.897

# %% [markdown]
# Application 1 - 30% prelim, 30% midterm, 40% final=sem grade
#
# 1. Create a Python program that displays the name of three students (Student 1, Student 2, Student 3) and their term grades
# 2. Create a class name Person and attributes - std1, std2, std3, pre, mid, fin
# 3. Compute the average of each term grade using Grade() method
# 4. Information about student's grades must be hidden from others

# %%
class Person:
  def __init__(self, name, pre, mid, fin):
    self._name = name
    self._pre = pre
    self._mid = mid
    self._fin = fin
  def Grades(self):
     return print("Student Recognized,", self._name, "you have a Semestral Grade of", self._pre* 0.30 + self._mid* 0.30 + self._fin* 0.40)


std1 = Person("Tanjiro Kalmado",76 ,94,82) 

std2 = Person("Rudy Baldwin",95,92,90)

std3 = Person("Jay Moral",89,91,100)

x = input(str("Input your student number from 01 to 03: "))

if x == "01":
  std1.Grades()
else:
  if x == "02":
    std2.Grades()
  else:
    if x == "03":
      std3.Grades()
    else:
      print("Invalid Student")
# Out:
# Input your student number from 01 to 03: 02
# Student Recognized, Rudy Baldwin you have a Semestral Grade of 92.1
